# %%
# !pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imutils in c:\users\jains\appdata\roaming\python\python39\site-packages (0.5.4)

# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %%
def load(paths, verbose=-1):
    '''expects images for each class in seperate dir, 
    e.g all digits in 0 class in the directory named 0 '''
    data = list()
    labels = list()
    # loop over the input images
    for (i, imgpath) in enumerate(paths):
        # load the image and extract the class labels
        im_gray = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
        im_gray=cv2.resize(im_gray,(160,160))
        image = np.array(im_gray).flatten()
        label = imgpath.split(os.path.sep)[-2]
        # scale the image to [0, 1] and add to list
        data.append(image/255)
        labels.append(label)
        # show an update every `verbose` images
        if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
            print("[INFO] processed {}/{}".format(i + 1, len(paths)))
    # return a tuple of the data and labels
    return data, labels

# %%
#declear path to your mnist data folder
img_path = 'DATASET'

#get the path list using the path object
image_paths = list(paths.list_images(img_path))

#apply our function
image_list, label_list = load(image_paths, verbose=10000)

#binarize the labels
lb = LabelBinarizer()
label_list = lb.fit_transform(label_list)

#split data into training and test set
X_train, X_test, y_train, y_test = train_test_split(image_list, 
                                                    label_list, 
                                                    test_size=0.1, 
                                                    random_state=42)

# %%
len(image_list)
# Out:
# 832

# %%
len(label_list)
# Out:
# 832

# %%
def create_clients(image_list, label_list, num_clients=10, initial='clients'):


   
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    data = list(zip(image_list, label_list))
    random.shuffle(data)

    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    assert(len(shards) == len(client_names))

    return {client_names[i] : shards[i] for i in range(len(client_names))}

# %%
clients = create_clients(X_train, y_train, num_clients=10, initial='client')

# %%
clients
# Out:
# {'client_1': [(array([1., 1., 1., ..., 1., 1., 1.]), array([0, 1, 0, 0])),
#   (array([0.18431373, 0.05882353, 0.0627451 , ..., 0.03529412, 0.01568627,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.99215686, 0.05490196, 0.09803922, ..., 1.        , 0.99607843,
#           0.99215686]),
#    array([0, 0, 0, 1])),
#   (array([0.29019608, 0.19215686, 0.        , ..., 0.00392157, 0.03529412,
#           0.02745098]),
#    array([0, 0, 0, 1])),
#   (array([0.03529412, 0.01960784, 0.03921569, ..., 0.01176471, 0.00392157,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.14901961, 0.13333333, 0.0745098 , ..., 0.00392157, 0.01568627,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.43921569, 0.44313725, 0.43921569, ..., 0.03137255, 0.04313725,
#           0.04705882]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00392157, 0.03137255,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 0.98431373, 0.99607843, ..., 0.05882353, 0.03529412,
#           0.01960784]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.00784314,
#           0.89803922]),
#    array([0, 1, 0, 0])),
#   (array([0.01960784, 0.10980392, 0.08627451, ..., 0.01960784, 0.00392157,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.98823529, 0.98431373,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.4       , 0.44705882, 0.49019608, ..., 0.01568627, 0.00392157,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.15686275, 0.12156863, 0.09019608, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.        , 0.06666667, ..., 0.03529412, 0.00784314,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.31764706, 0.46666667, 0.41960784, ..., 0.01176471, 0.00784314,
#           0.02352941]),
#    array([1, 0, 0, 0])),
#   (array([0.03529412, 0.05882353, 0.01568627, ..., 0.        , 0.        ,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.10588235, 0.12156863, 0.17647059, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.14509804, 0.08235294, 0.03137255, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.17647059, 0.19607843, 0.07058824, ..., 0.00784314, 0.02352941,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.23921569, 0.0627451 , 0.13333333, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.01176471, 0.06666667, 0.01568627, ..., 0.01960784, 0.01176471,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01176471, 0.00392157,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.02745098, 0.01960784,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.08627451, 0.08235294, ..., 0.02745098, 0.03529412,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.00784314,
#           0.90196078]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.02745098,
#           0.00392157]),
#    array([0, 0, 1, 0])),
#   (array([0.03529412, 0.02745098, 0.11764706, ..., 0.00392157, 0.01568627,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.1254902 , 0.08627451, 0.09803922, ..., 0.99607843, 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 0, 1])),
#   (array([0.91764706, 0.1254902 , 0.15294118, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.01176471, 0.15294118, 0.11372549, ..., 0.02745098, 0.03529412,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.03137255,
#           0.04705882]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02352941, 0.02352941,
#           0.89019608]),
#    array([0, 1, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([1, 0, 0, 0])),
#   (array([0.03137255, 0.00392157, 0.08627451, ..., 0.01960784, 0.00784314,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.13333333, 0.02745098, 0.15294118, ..., 0.01568627, 0.00392157,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.05490196,
#           0.03137255]),
#    array([0, 1, 0, 0])),
#   (array([0.14117647, 0.00784314, 0.18431373, ..., 0.03529412, 0.05098039,
#           0.03137255]),
#    array([0, 1, 0, 0])),
#   (array([0.12941176, 0.12941176, 0.09803922, ..., 0.        , 0.01960784,
#           0.01176471]),
#    array([0, 0, 1, 0])),
#   (array([0.00392157, 0.00784314, 0.00392157, ..., 0.02745098, 0.01176471,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.32941176, 0.05098039, 0.01176471, ..., 0.02745098, 0.04705882,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.97647059, 0.99215686,
#           0.99215686]),
#    array([0, 1, 0, 0])),
#   (array([0.21568627, 0.16078431, 0.25490196, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.01176471,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.02745098, 0.01960784, 0.02352941, ..., 0.01960784, 0.00392157,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.09019608, 0.09803922, 0.02745098, ..., 0.        , 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.11764706, 0.1254902 , 0.09019608, ..., 0.94509804, 0.90196078,
#           0.89411765]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.01960784, 0.01176471, ..., 0.01176471, 0.01176471,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.17647059, 0.14117647, 0.09019608, ..., 0.01960784, 0.00392157,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([0.07058824, 0.16078431, 0.16470588, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.00784314, 0.24705882, 0.07058824, ..., 0.        , 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.04705882,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.99215686, 1.        , 0.99607843, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.03921569,
#           0.04705882]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.03137255,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.02352941, 0.        , ..., 0.03137255, 0.        ,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.01176471, 0.06666667, 0.01568627, ..., 0.01960784, 0.01176471,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([0.14117647, 0.10588235, 0.12156863, ..., 0.00784314, 0.00784314,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.95294118, 0.95294118, 0.95686275, ..., 0.04313725, 0.01960784,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.09411765, 0.05882353,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.        , 0.41568627, ..., 0.05098039, 0.02745098,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.06666667, 0.14509804, 0.00392157, ..., 0.        , 0.01176471,
#           0.01568627]),
#    array([0, 0, 1, 0])),
#   (array([0.09411765, 0.08235294, 0.11372549, ..., 0.02745098, 0.01568627,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.09803922, 0.07058824, ..., 0.02745098, 0.02352941,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([0.00392157, 0.00392157, 0.00392157, ..., 0.01960784, 0.00392157,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([1, 0, 0, 0])),
#   (array([0.08627451, 0.04313725, 0.06666667, ..., 0.98431373, 0.99215686,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.02352941,
#           0.03921569]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.02745098,
#           0.05882353]),
#    array([0, 0, 1, 0])),
#   (array([0.24705882, 0.16862745, 0.10588235, ..., 0.02745098, 0.04313725,
#           0.05882353]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01568627, 0.05490196,
#           0.03137255]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.06666667, 0.08627451,
#           0.02352941]),
#    array([0, 0, 1, 0])),
#   (array([0.99215686, 0.99607843, 1.        , ..., 0.03137255, 0.01176471,
#           0.01960784]),
#    array([1, 0, 0, 0]))],
#  'client_2': [(array([0.09411765, 0.09019608, 0.08235294, ..., 0.01176471, 0.01176471,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.23529412, 0.28235294, ..., 0.00392157, 0.01176471,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.90980392, 0.07058824, 0.14117647, ..., 0.03137255, 0.03921569,
#           0.03529412]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.02352941, 0.04705882, ..., 0.01568627, 0.03137255,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.10196078, 0.15686275, 0.15686275, ..., 0.00784314, 0.00784314,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.16470588, 0.08235294, 0.01176471, ..., 0.01568627, 0.01960784,
#           0.02352941]),
#    array([0, 0, 1, 0])),
#   (array([0.18431373, 0.05882353, 0.0627451 , ..., 0.03529412, 0.01568627,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.0627451 , 0.05490196,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([0.01176471, 0.03529412, 0.09803922, ..., 0.00784314, 0.        ,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.1254902 , 0.08627451, 0.09803922, ..., 0.99607843, 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 0.12156863, 0.05098039, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.00784314, 0.11764706, 0.14901961, ..., 0.03529412, 0.03529412,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.09803922, 0.01960784, ..., 0.03137255, 0.03137255,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([0.01960784, 0.0627451 , 0.12156863, ..., 0.00392157, 0.00784314,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.14509804, 0.20784314, 0.1372549 , ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.00392157, 0.03921569,
#           0.04313725]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.00392157, 0.        ,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.99607843, 0.98039216,
#           0.99215686]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.01176471, 0.05490196, ..., 0.00392157, 0.02745098,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.06666667, 0.14117647, 0.10588235, ..., 0.01176471, 0.01176471,
#           0.03137255]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.03529412,
#           0.02745098]),
#    array([0, 0, 0, 1])),
#   (array([0.02745098, 0.00392157, 0.08235294, ..., 0.01960784, 0.01568627,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.20784314, 0.14509804, 0.12156863, ..., 1.        , 0.99607843,
#           0.99607843]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.05490196,
#           0.90196078]),
#    array([0, 1, 0, 0])),
#   (array([0.0627451 , 0.10196078, 0.18431373, ..., 0.04705882, 0.04313725,
#           0.01568627]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.        , 0.02352941,
#           0.01176471]),
#    array([0, 0, 1, 0])),
#   (array([0.31764706, 0.46666667, 0.41960784, ..., 0.01176471, 0.00784314,
#           0.02352941]),
#    array([1, 0, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([1, 0, 0, 0])),
#   (array([0.00392157, 0.01176471, 0.02745098, ..., 0.01176471, 0.01960784,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.04705882, 0.00784314, 0.07843137, ..., 0.00784314, 0.01176471,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.0627451 , 0.05882353,
#           0.06666667]),
#    array([0, 0, 1, 0])),
#   (array([0.03137255, 0.0745098 , 0.16470588, ..., 1.        , 1.        ,
#           0.99607843]),
#    array([0, 1, 0, 0])),
#   (array([0.00392157, 0.02745098, 0.01960784, ..., 0.        , 0.00784314,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.1372549 , 0.16078431, 0.03921569, ..., 0.00784314, 0.01568627,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.00392157, 0.22745098, 0.14509804, ..., 0.        , 0.        ,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.0627451 , 0.01568627, 0.08627451, ..., 0.01176471, 0.00392157,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.15686275, 0.13333333, 0.14901961, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.08235294,
#           0.03921569]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.98823529, 0.99215686,
#           0.99215686]),
#    array([1, 0, 0, 0])),
#   (array([0.90980392, 0.09803922, 0.1254902 , ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.00784314, 0.04313725, 0.        , ..., 0.        , 0.00784314,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.01176471, 0.00784314, 0.09019608, ..., 0.01176471, 0.        ,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.05098039, 0.10196078, ..., 0.03529412, 0.03921569,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.97254902, 0.98823529,
#           0.98823529]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.01568627, 0.03529412, ..., 0.01176471, 0.01176471,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.03137255,
#           0.05490196]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.01176471,
#           0.03921569]),
#    array([0, 1, 0, 0])),
#   (array([0.00392157, 0.0627451 , 0.10196078, ..., 0.02352941, 0.00784314,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.15686275, 0.08235294, 0.06666667, ..., 0.02352941, 0.05098039,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.90588235, 0.90588235, 0.90980392, ..., 0.03137255, 0.03137255,
#           0.05098039]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00392157, 0.03137255,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.99607843, 1.        , 0.25490196, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.03921569,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([0.07058824, 0.09019608, 0.05490196, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.05098039, 0.03137255, 0.00784314, ..., 0.01176471, 0.01176471,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.04313725, 0.03529412, 0.00392157, ..., 0.        , 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.10980392, 0.08627451, 0.0745098 , ..., 0.03137255, 0.01568627,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.01568627, 0.04705882,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.99607843, 1.        , 1.        , ..., 0.01176471, 0.00392157,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.13333333, 0.05098039, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.11764706, 0.01568627, 0.10196078, ..., 0.01176471, 0.00784314,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.94901961, 0.94901961, 0.95294118, ..., 0.01568627, 0.01568627,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.05098039,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.09411765, 0.08235294, ..., 0.01176471, 0.03529412,
#           0.03921569]),
#    array([0, 0, 0, 1])),
#   (array([0.11372549, 0.06666667, 0.1254902 , ..., 0.00392157, 0.02745098,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.00392157, 0.08627451, 0.12941176, ..., 0.06666667, 0.04705882,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.13333333, 0.10588235,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.08627451, 0.04313725,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([0.03137255, 0.12941176, 0.17647059, ..., 0.02745098, 0.03137255,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.99215686, 1.        , 0.99607843, ..., 0.02352941, 0.01568627,
#           0.02352941]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01568627, 0.04705882,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.92156863, 0.17647059, 0.14117647, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.05098039,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([0.09411765, 0.11372549, 0.12156863, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0]))],
#  'client_3': [(array([0.90588235, 0.90588235, 0.90980392, ..., 0.03137255, 0.03137255,
#           0.05098039]),
#    array([0, 1, 0, 0])),
#   (array([0.02745098, 0.00392157, 0.08627451, ..., 0.01960784, 0.01176471,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([1, 0, 0, 0])),
#   (array([0.01176471, 0.03529412, 0.00784314, ..., 0.00392157, 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.00392157, 0.00784314, 0.02745098, ..., 0.00784314, 0.01568627,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.01176471, 0.02352941, ..., 0.02745098, 0.02352941,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.00784314,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.09019608, 0.08235294,
#           0.90588235]),
#    array([0, 1, 0, 0])),
#   (array([0.0745098 , 0.1372549 , 0.07058824, ..., 0.03137255, 0.03137255,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([0.01960784, 0.        , 0.1372549 , ..., 0.01176471, 0.01960784,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.05098039,
#           0.03921569]),
#    array([0, 1, 0, 0])),
#   (array([0.01176471, 0.07843137, 0.04705882, ..., 0.01176471, 0.02745098,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.02745098, 0.0627451 , 0.05490196, ..., 0.01176471, 0.01176471,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.16078431, 0.01568627, 0.12156863, ..., 0.01176471, 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.00784314, 0.00784314, 0.02352941, ..., 0.00392157, 0.00392157,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.01960784, 0.03137255, 0.        , ..., 0.00392157, 0.03137255,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.03137255, 0.06666667, 0.03137255, ..., 0.01176471, 0.00392157,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.09019608, 0.14117647, 0.05098039, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.14901961, 0.10588235,
#           0.05490196]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.15294118, 0.08235294, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.09411765, 0.02352941,
#           0.05098039]),
#    array([1, 0, 0, 0])),
#   (array([0.10980392, 0.05490196, 0.08627451, ..., 0.01960784, 0.00392157,
#           0.89803922]),
#    array([0, 1, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.01568627, 0.17647059, 0.        , ..., 0.04313725, 0.03921569,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.03921569,
#           0.02352941]),
#    array([0, 0, 0, 1])),
#   (array([0.08627451, 0.22352941, 0.14117647, ..., 0.05490196, 0.04705882,
#           0.02745098]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.12156863, 0.10588235, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.97254902, 0.99607843, 0.99215686, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.02745098, 0.02745098, ..., 0.        , 0.00784314,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02352941, 0.01960784,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([0.07058824, 0.01176471, 0.04313725, ..., 0.00392157, 0.00784314,
#           0.00392157]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 0.98431373, 0.99607843, ..., 0.05882353, 0.03529412,
#           0.01960784]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.05882353, 0.01176471, ..., 0.01568627, 0.01176471,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.00392157, 0.00392157, 0.01960784, ..., 0.02745098, 0.02745098,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([0.15294118, 0.0745098 , 0.05490196, ..., 0.99215686, 1.        ,
#           0.99215686]),
#    array([0, 0, 1, 0])),
#   (array([0.95294118, 1.        , 1.        , ..., 0.04313725, 0.07058824,
#           0.01176471]),
#    array([0, 0, 1, 0])),
#   (array([0.19215686, 0.21176471, 0.19215686, ..., 0.07058824, 0.05490196,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.90196078, 0.25490196, 0.26666667, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.01176471,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.03137255, 0.14117647, 0.01176471, ..., 0.02352941, 0.03921569,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.09411765, 0.09411765, 0.11372549, ..., 0.00392157, 0.01568627,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.05490196, 0.10588235, 0.05882353, ..., 0.01176471, 0.00784314,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.08627451, 0.10196078, 0.04705882, ..., 0.02352941, 0.01176471,
#           0.01568627]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05098039, 0.04313725,
#           0.03137255]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.02352941,
#           0.11372549]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.09019608, 0.07843137,
#           0.0627451 ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01176471, 0.04313725,
#           0.88627451]),
#    array([0, 0, 1, 0])),
#   (array([0.92156863, 0.9372549 , 0.95294118, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.00392157, 0.01176471, 0.02745098, ..., 0.01176471, 0.01960784,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.00784314, 0.03529412, 0.12941176, ..., 0.01176471, 0.00392157,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.16862745, 0.08627451, 0.0627451 , ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.14117647, 0.00784314, 0.18431373, ..., 0.03529412, 0.05098039,
#           0.03137255]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.01960784,
#           0.0745098 ]),
#    array([0, 1, 0, 0])),
#   (array([0.16862745, 0.16862745, 0.18823529, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.08235294, 0.04313725, 0.04313725, ..., 0.99215686, 0.99215686,
#           0.99215686]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.05490196,
#           0.04705882]),
#    array([0, 0, 0, 1])),
#   (array([0.04313725, 0.03529412, 0.09411765, ..., 0.01960784, 0.02745098,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.03529412,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.        , 0.        , ..., 0.00784314, 0.00392157,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.04313725,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.1254902 , 0.07843137,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([0.00784314, 0.01176471, 0.01568627, ..., 0.00784314, 0.00784314,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 0.99607843, 0.10588235, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00392157, 0.00392157,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.03137255, 0.07058824, 0.08627451, ..., 0.02352941, 0.02745098,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([0.11764706, 0.09411765, 0.13333333, ..., 0.94901961, 0.92941176,
#           0.04313725]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.05098039, 0.02745098,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.2       , 0.11764706, 0.08235294, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.02745098,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.10588235, 0.03921569, ..., 0.        , 0.        ,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.07058824, 0.01960784, 0.05098039, ..., 0.01176471, 0.01568627,
#           0.03137255]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.01568627,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.00392157, 0.03921569,
#           0.04313725]),
#    array([1, 0, 0, 0]))],
#  'client_4': [(array([0.14117647, 0.11372549, 0.16078431, ..., 0.01176471, 0.00392157,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.01568627, 0.03529412,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.00392157,
#           0.90196078]),
#    array([0, 1, 0, 0])),
#   (array([0.03529412, 0.00392157, 0.10196078, ..., 0.01568627, 0.        ,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04705882, 0.05098039,
#           0.05098039]),
#    array([0, 0, 1, 0])),
#   (array([0.95294118, 0.94117647, 0.95294118, ..., 0.01176471, 0.01960784,
#           0.07843137]),
#    array([1, 0, 0, 0])),
#   (array([0.92156863, 0.9372549 , 0.95294118, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.03137255,
#           0.01568627]),
#    array([0, 0, 1, 0])),
#   (array([0.17647059, 0.11764706, 0.09803922, ..., 0.03137255, 0.01176471,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.01176471, 0.00784314, 0.05490196, ..., 0.00784314, 0.        ,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.08235294, 0.10196078, 0.10196078, ..., 0.01176471, 0.00392157,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.        , 0.        , 0.05098039, ..., 0.00784314, 0.        ,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.05882353, 0.00784314, 0.01960784, ..., 0.00784314, 0.00784314,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.23529412, 0.29803922, 0.23529412, ..., 0.07843137, 0.01568627,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.00392157, 0.03921569, ..., 0.02352941, 0.02352941,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.05098039,
#           0.03921569]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.02745098,
#           0.05882353]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.11764706, 0.11372549,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.06666667, 0.05098039,
#           0.05490196]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.03921569,
#           0.01568627]),
#    array([0, 0, 1, 0])),
#   (array([0.03921569, 0.03921569, 0.05490196, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.09019608, 0.09019608, 0.14901961, ..., 0.00784314, 0.01568627,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.09019608, 0.08235294, 0.04313725, ..., 0.01568627, 0.00392157,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.04705882,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.98431373, 0.99215686,
#           0.99607843]),
#    array([0, 1, 0, 0])),
#   (array([0.07058824, 0.04313725, 0.        , ..., 0.03529412, 0.01960784,
#           0.02745098]),
#    array([0, 0, 0, 1])),
#   (array([0.01960784, 0.        , 0.1372549 , ..., 0.01176471, 0.01960784,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.00392157, 0.04313725, ..., 0.02745098, 0.01960784,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.08627451, 0.00784314, 0.05490196, ..., 0.02352941, 0.03137255,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([0.11372549, 0.09411765, 0.10588235, ..., 0.00784314, 0.00392157,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.03921569, 0.04705882, 0.03921569, ..., 0.00784314, 0.00392157,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.14117647, 0.16078431, 0.09411765, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.05882353,
#           0.01960784]),
#    array([0, 0, 1, 0])),
#   (array([0.03529412, 0.1254902 , 0.03921569, ..., 0.03137255, 0.00784314,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([0.17254902, 0.14117647, 0.1254902 , ..., 0.98823529, 0.99607843,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.03137255, 0.08627451, 0.14901961, ..., 0.90588235, 0.90588235,
#           0.89411765]),
#    array([0, 1, 0, 0])),
#   (array([0.14901961, 0.12941176, 0.14509804, ..., 0.01176471, 0.02352941,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.00392157, 0.00392157, 0.00392157, ..., 0.01960784, 0.00392157,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.0745098 , 0.08235294, ..., 0.99607843, 0.99607843,
#           0.91372549]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02352941, 0.01568627,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.04705882, 0.03529412,
#           0.02352941]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.09411765, 0.06666667, ..., 0.01960784, 0.03137255,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02352941, 0.02352941,
#           0.89019608]),
#    array([0, 1, 0, 0])),
#   (array([0.04705882, 0.02745098, 0.02352941, ..., 0.00784314, 0.00784314,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.00784314, 0.0745098 ,
#           0.05490196]),
#    array([0, 0, 0, 1])),
#   (array([0.13333333, 0.12156863, 0.10588235, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 0.99607843, 0.97647059, ..., 0.90588235, 0.90980392,
#           0.90980392]),
#    array([0, 1, 0, 0])),
#   (array([0.03137255, 0.05098039, 0.03529412, ..., 0.01960784, 0.00392157,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.05882353, 0.02352941, 0.07843137, ..., 0.05490196, 0.03137255,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.02745098, 0.12156863, 0.        , ..., 0.01568627, 0.00784314,
#           0.02352941]),
#    array([0, 0, 1, 0])),
#   (array([0.99215686, 0.99607843, 1.        , ..., 0.03137255, 0.01176471,
#           0.01960784]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.08627451, 0.05882353, ..., 0.        , 0.        ,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.02352941, 0.06666667, 0.00392157, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.04313725, 0.01568627, 0.07843137, ..., 0.01176471, 0.01568627,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([0.02352941, 0.03921569, 0.01568627, ..., 0.01176471, 0.02352941,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.00784314, 0.16862745, 0.14117647, ..., 0.03529412, 0.02352941,
#           0.89803922]),
#    array([0, 0, 1, 0])),
#   (array([0.99607843, 1.        , 1.        , ..., 0.03529412, 0.01568627,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.19607843, 0.15294118, 0.11372549, ..., 0.03921569, 0.04705882,
#           0.03921569]),
#    array([1, 0, 0, 0])),
#   (array([0.05098039, 0.03137255, 0.00392157, ..., 0.00784314, 0.        ,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.90196078, 0.11764706, 0.14117647, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.13333333, 0.        , 0.19215686, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.03137255, 0.08235294, 0.09019608, ..., 0.03921569, 0.01960784,
#           0.01960784]),
#    array([1, 0, 0, 0])),
#   (array([0.03137255, 0.00392157, 0.08627451, ..., 0.01960784, 0.00784314,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.03529412,
#           0.03921569]),
#    array([0, 0, 0, 1])),
#   (array([0.99215686, 0.99607843, 0.99215686, ..., 0.01960784, 0.00784314,
#           0.02352941]),
#    array([0, 0, 0, 1])),
#   (array([0.88235294, 0.04313725, 0.12156863, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.08627451, 0.00392157,
#           0.04705882]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.08627451, 0.04313725,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.0745098 , 0.1372549 , 0.07058824, ..., 0.03137255, 0.03137255,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([0.08627451, 0.15294118, 0.10196078, ..., 1.        , 0.99607843,
#           0.99215686]),
#    array([0, 0, 0, 1])),
#   (array([0.09411765, 0.02745098, 0.01960784, ..., 0.        , 0.        ,
#           0.01568627]),
#    array([0, 1, 0, 0]))],
#  'client_5': [(array([0.00784314, 0.04313725, 0.        , ..., 0.        , 0.00784314,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.14901961, 0.09411765, 0.12941176, ..., 0.02352941, 0.03137255,
#           0.89803922]),
#    array([1, 0, 0, 0])),
#   (array([0.96862745, 0.99607843, 0.99607843, ..., 0.99215686, 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04705882, 0.04705882,
#           0.03137255]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.01568627, 0.07843137, ..., 0.01176471, 0.01568627,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02352941, 0.02352941,
#           0.02352941]),
#    array([1, 0, 0, 0])),
#   (array([0.27058824, 0.20784314, 0.29411765, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 0.12156863, 0.05098039, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.03921569,
#           0.05882353]),
#    array([0, 0, 0, 1])),
#   (array([0.20392157, 0.09019608, 0.        , ..., 0.05882353, 0.02745098,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.01960784, 0.15294118, 0.14509804, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.09411765, 0.12156863, 0.04705882, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.09803922, 0.0627451 , 0.11372549, ..., 0.        , 0.01568627,
#           0.01960784]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 0.97647059, 0.99607843, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.02352941, 0.03921569, 0.01568627, ..., 0.01176471, 0.02352941,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.00392157, 0.03529412, 0.02352941, ..., 0.0627451 , 0.05882353,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.02745098, 0.00392157, 0.07843137, ..., 0.01960784, 0.01568627,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.01960784, 0.0627451 , 0.03137255, ..., 0.00392157, 0.00784314,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.01568627, 0.0627451 , 0.21960784, ..., 0.99607843, 0.97647059,
#           0.99607843]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00784314, 0.00784314,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.08235294, 0.05882353, 0.11764706, ..., 0.01960784, 0.00784314,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.01176471, 0.        , 0.0627451 , ..., 0.00784314, 0.00784314,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.14509804, 0.14509804, 0.1372549 , ..., 0.01176471, 0.        ,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.03921569,
#           0.04705882]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.0627451 , 0.06666667,
#           0.03921569]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.01568627, 0.03529412, ..., 0.01176471, 0.01176471,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([0.14117647, 0.18431373, 0.16078431, ..., 0.03529412, 0.07058824,
#           0.07843137]),
#    array([0, 0, 0, 1])),
#   (array([0.03529412, 0.12156863, 0.09019608, ..., 0.01176471, 0.01568627,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.0627451 , 0.07843137, 0.08235294, ..., 0.03137255, 0.01568627,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([0.07058824, 0.01960784, 0.05098039, ..., 0.01176471, 0.01568627,
#           0.03137255]),
#    array([1, 0, 0, 0])),
#   (array([0.06666667, 0.04705882, 0.15294118, ..., 0.03137255, 0.05882353,
#           0.04705882]),
#    array([0, 0, 0, 1])),
#   (array([0.02352941, 0.17254902, 0.00784314, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.02352941, 0.15294118, ..., 0.01176471, 0.        ,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.05490196,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.1372549 , 0.32156863, 0.37254902, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.07058824, 0.02352941, 0.10196078, ..., 0.01960784, 0.01960784,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.10196078, 0.00784314, 0.01568627, ..., 0.0745098 , 0.01176471,
#           0.05098039]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05098039, 0.01176471,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 0.00784314, 0.00392157, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.14509804, 0.14117647, 0.12941176, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 1, 0, 0])),
#   (array([0.00392157, 0.22745098, 0.14509804, ..., 0.        , 0.        ,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.03137255, 0.00392157, 0.0745098 , ..., 0.01960784, 0.01176471,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05098039, 0.01960784,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00784314, 0.00392157,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([0.08235294, 0.04313725, 0.04313725, ..., 0.99215686, 0.99215686,
#           0.99215686]),
#    array([0, 1, 0, 0])),
#   (array([0.05882353, 0.00784314, 0.01960784, ..., 0.00784314, 0.00784314,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.20784314, 0.14509804, 0.12156863, ..., 1.        , 0.99607843,
#           0.99607843]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.01568627, 0.06666667, ..., 0.02745098, 0.02745098,
#           0.02352941]),
#    array([0, 0, 0, 1])),
#   (array([0.03529412, 0.15294118, 0.03529412, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.10196078, 0.05490196,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.02745098,
#           0.06666667]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05882353, 0.04313725,
#           0.03921569]),
#    array([0, 0, 1, 0])),
#   (array([0.09411765, 0.05882353, 0.08627451, ..., 0.01568627, 0.        ,
#           0.01176471]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.98823529, 0.98431373,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.08235294, 0.13333333, 0.19215686, ..., 0.00784314, 0.00392157,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.98823529, 0.90588235, 0.89411765, ..., 0.01568627, 0.02352941,
#           0.02352941]),
#    array([0, 1, 0, 0])),
#   (array([0.90196078, 0.11764706, 0.14117647, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.05098039, 0.01176471, 0.03529412, ..., 0.01176471, 0.01568627,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.16078431, 0.08627451,
#           0.09411765]),
#    array([1, 0, 0, 0])),
#   (array([0.91764706, 0.14117647, 0.03921569, ..., 0.03137255, 0.03921569,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([0.15294118, 0.12156863, 0.18431373, ..., 0.98431373, 1.        ,
#           0.99607843]),
#    array([1, 0, 0, 0])),
#   (array([0.03529412, 0.03529412, 0.05882353, ..., 0.00784314, 0.00392157,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.03137255, 0.05098039, 0.15686275, ..., 0.00784314, 0.01568627,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.01960784, 0.05098039, ..., 0.00784314, 0.01176471,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.04705882, 0.2627451 , 0.27058824, ..., 0.01176471, 0.00784314,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.03529412,
#           0.02745098]),
#    array([0, 1, 0, 0])),
#   (array([0.13333333, 0.11372549, 0.11764706, ..., 0.03921569, 0.0627451 ,
#           0.00392157]),
#    array([0, 0, 1, 0])),
#   (array([0.01568627, 0.17254902, 0.08627451, ..., 0.03921569, 0.05882353,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.05882353, 0.02745098, 0.04705882, ..., 0.04313725, 0.02745098,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.98431373, 0.99215686,
#           0.99607843]),
#    array([0, 1, 0, 0])),
#   (array([0.2       , 0.11764706, 0.08235294, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0]))],
#  'client_6': [(array([0.07058824, 0.0627451 , 0.05490196, ..., 0.00784314, 0.01568627,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.00784314,
#           0.89803922]),
#    array([0, 1, 0, 0])),
#   (array([0.05098039, 0.01176471, 0.03529412, ..., 0.01176471, 0.01568627,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.90196078, 0.25490196, 0.26666667, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.11764706, 0.15294118, 0.03529412, ..., 0.02745098, 0.01568627,
#           0.03137255]),
#    array([0, 0, 1, 0])),
#   (array([0.08627451, 0.1372549 , 0.1372549 , ..., 0.02352941, 0.03137255,
#           0.01960784]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.00784314, 0.02352941,
#           0.07058824]),
#    array([0, 0, 0, 1])),
#   (array([0.00392157, 0.05882353, 0.03137255, ..., 0.00784314, 0.01176471,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.09411765, 0.03529412, 0.05882353, ..., 0.        , 0.00784314,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.00784314, 0.14509804, 0.18823529, ..., 0.02352941, 0.01176471,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([0.15686275, 0.08235294, 0.06666667, ..., 0.02352941, 0.05098039,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.12156863, 0.25490196, 0.01176471, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.3372549 , 0.31764706, 0.34901961, ..., 0.01960784, 0.06666667,
#           0.02745098]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.04313725,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([0.03529412, 0.12156863, 0.09019608, ..., 0.01176471, 0.01568627,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.03529412, 0.16078431, 0.14117647, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.09803922, 0.18431373, 0.13333333, ..., 0.00392157, 0.05098039,
#           0.0627451 ]),
#    array([1, 0, 0, 0])),
#   (array([0.14901961, 0.14901961, 0.20392157, ..., 0.00392157, 0.01176471,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([1, 0, 0, 0])),
#   (array([1.        , 0.99607843, 0.97647059, ..., 0.90588235, 0.90980392,
#           0.90980392]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.03137255, 0.03529412, ..., 0.01568627, 0.01176471,
#           0.02352941]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 0.16470588, 0.15686275, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.38039216, 0.30980392, 0.0745098 , ..., 0.00392157, 0.01960784,
#           0.00784314]),
#    array([0, 0, 0, 1])),
# ...
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.00784314, 0.01176471, 0.01568627, ..., 0.00784314, 0.00784314,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.1372549 , 0.01568627, 0.14117647, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.97254902, 0.98823529,
#           0.98823529]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.        , 0.00392157, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.08627451, 0.02352941,
#           0.05882353]),
#    array([0, 0, 1, 0])),
#   (array([0.08235294, 0.06666667, 0.1372549 , ..., 0.00784314, 0.04313725,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.90196078, 0.07058824, 0.05882353, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.90980392, 0.01568627, 0.17647059, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.03529412, 0.00392157, 0.10196078, ..., 0.01568627, 0.        ,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.0627451 , 0.06666667, 0.04313725, ..., 0.03137255, 0.00392157,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.90980392, 0.01568627, 0.09019608, ..., 0.02745098, 0.0627451 ,
#           0.03529412]),
#    array([1, 0, 0, 0])),
#   (array([0.15294118, 0.11372549, 0.09019608, ..., 0.03529412, 0.01960784,
#           0.09411765]),
#    array([1, 0, 0, 0])),
#   (array([0.02745098, 0.03921569, 0.07843137, ..., 0.02352941, 0.01176471,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.00784314, 0.08235294, 0.09803922, ..., 0.04313725, 0.05882353,
#           0.02352941]),
#    array([0, 0, 1, 0])),
#   (array([0.15686275, 0.04313725, 0.08235294, ..., 0.02745098, 0.01960784,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.07843137, 0.03529412,
#           0.90588235]),
#    array([0, 1, 0, 0])),
#   (array([0.01960784, 0.03137255, 0.        , ..., 0.00392157, 0.03137255,
#           0.01568627]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.07843137, 0.01960784, ..., 0.00784314, 0.02745098,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.00784314, 0.0745098 , 0.00784314, ..., 0.00392157, 0.01176471,
#           0.00392157]),
#    array([0, 0, 1, 0])),
#   (array([0.11764706, 0.11764706, 0.10980392, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.04313725, 0.00392157, 0.0745098 , ..., 0.00784314, 0.01568627,
#           0.01960784]),
#    array([1, 0, 0, 0])),
#   (array([0.0627451 , 0.        , 0.10196078, ..., 0.01176471, 0.02745098,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.05098039, 0.03921569, 0.02745098, ..., 0.01176471, 0.00784314,
#           0.01176471]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01568627, 0.02352941,
#           0.03529412]),
#    array([0, 0, 1, 0])),
#   (array([0.00392157, 0.        , 0.07843137, ..., 0.01176471, 0.        ,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([0.04705882, 0.05882353, 0.10980392, ..., 0.00784314, 0.01568627,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.00392157, 0.        , 0.07843137, ..., 0.01176471, 0.        ,
#           0.00784314]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.51764706, 0.99215686,
#           0.95686275]),
#    array([0, 0, 0, 1])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.92156863, 0.17647059, 0.14117647, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00392157, 0.00784314,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.12941176, 0.06666667, 0.17254902, ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.05098039, 0.03529412, ..., 0.00784314, 0.00392157,
#           0.00392157]),
#    array([0, 0, 1, 0])),
#   (array([0.03137255, 0.07058824, 0.08627451, ..., 0.02352941, 0.02745098,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([0.01176471, 0.12156863, 0.11372549, ..., 0.03529412, 0.02352941,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.02352941,
#           0.02352941]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.01960784, 0.05098039,
#           0.03921569]),
#    array([0, 0, 0, 1])),
#   (array([0.14901961, 0.02352941, 0.11372549, ..., 0.01176471, 0.0627451 ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.05882353, 0.08235294, 0.14509804, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.02745098, 0.00392157, 0.07843137, ..., 0.01960784, 0.01568627,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.0627451 , 0.01568627, 0.08627451, ..., 0.01176471, 0.00392157,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.01960784, 0.01568627, 0.04313725, ..., 0.04313725, 0.00784314,
#           0.01176471]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.00392157, 0.11372549, ..., 0.01568627, 0.00784314,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.19215686, 0.03137255, 0.14509804, ..., 0.        , 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.01176471,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.01960784, 0.07058824, 0.1372549 , ..., 1.        , 1.        ,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.00784314, 0.14509804, 0.18823529, ..., 0.02352941, 0.01176471,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([0.05882353, 0.04313725, 0.23137255, ..., 0.03921569, 0.03529412,
#           0.03921569]),
#    array([0, 0, 0, 1])),
#   (array([0.03137255, 0.05098039, 0.03529412, ..., 0.01960784, 0.00392157,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.09411765, 0.05882353, 0.08627451, ..., 0.01568627, 0.        ,
#           0.01176471]),
#    array([0, 0, 1, 0])),
#   (array([0.04705882, 0.14117647, 0.13333333, ..., 0.02745098, 0.02352941,
#           0.02352941]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.0627451 , 0.05490196,
#           0.04313725]),
#    array([0, 0, 1, 0])),
#   (array([0.00784314, 0.24705882, 0.07058824, ..., 0.        , 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.03921569, 0.14117647, 0.05098039, ..., 0.03137255, 0.03137255,
#           0.02745098]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03529412, 0.10588235,
#           0.01960784]),
#    array([1, 0, 0, 0]))],
#  'client_10': [(array([0.        , 0.01960784, 0.01176471, ..., 0.01176471, 0.01176471,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.00392157, 0.01960784, 0.03921569, ..., 0.01176471, 0.01176471,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.04705882, 0.00784314, 0.07843137, ..., 0.00784314, 0.01176471,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05490196, 0.02745098,
#           0.06666667]),
#    array([0, 0, 1, 0])),
#   (array([0.0627451 , 0.10196078, 0.00392157, ..., 0.00392157, 0.01568627,
#           0.02745098]),
#    array([1, 0, 0, 0])),
#   (array([0.02745098, 0.09019608, 0.04705882, ..., 0.03529412, 0.02352941,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.97647059, 0.29411765, 0.30196078, ..., 0.00392157, 0.03529412,
#           0.99607843]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.09019608, 0.07843137,
#           0.0627451 ]),
#    array([0, 0, 1, 0])),
#   (array([0.03529412, 0.1372549 , 0.20392157, ..., 0.00784314, 0.        ,
#           0.02352941]),
#    array([0, 0, 1, 0])),
#   (array([0.01960784, 0.14901961, 0.06666667, ..., 0.05882353, 0.04705882,
#           0.03921569]),
#    array([1, 0, 0, 0])),
#   (array([0.02352941, 0.06666667, 0.05882353, ..., 0.01960784, 0.01568627,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.07843137, 0.0627451 ,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.06666667, 0.04313725, 0.04705882, ..., 0.00784314, 0.        ,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.01176471,
#           0.03921569]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.        , 0.        , ..., 0.00784314, 0.00784314,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.01176471, 0.12941176, 0.2       , ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.05882353, 0.08235294, 0.14509804, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.00784314, 0.07843137, 0.00784314, ..., 0.01176471, 0.02352941,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.04313725, 0.03137255, 0.03137255, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.00392157, 0.00784314, ..., 0.00392157, 0.00392157,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.11372549, 0.02745098, 0.10196078, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.14509804, 0.00392157, 0.12941176, ..., 0.03137255, 0.01568627,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([0.00784314, 0.02352941, 0.01176471, ..., 0.02352941, 0.01960784,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.15686275, 0.13333333, 0.23921569, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.16470588, 0.15294118, 0.09803922, ..., 0.99607843, 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.        , 0.09803922, 0.07058824, ..., 0.01960784, 0.00784314,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([0.03137255, 0.00392157, 0.0745098 , ..., 0.01960784, 0.01176471,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.05882353, 0.16470588, 0.04313725, ..., 0.99607843, 0.99607843,
#           0.99607843]),
#    array([0, 0, 0, 1])),
#   (array([0.03529412, 0.03529412, 0.05882353, ..., 0.00784314, 0.00392157,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.99215686, 0.94117647, 0.95686275, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.15294118, 0.0745098 , 0.05490196, ..., 0.99215686, 1.        ,
#           0.99215686]),
#    array([0, 0, 1, 0])),
#   (array([0.03137255, 0.08627451, 0.14901961, ..., 0.90588235, 0.90588235,
#           0.89411765]),
#    array([0, 1, 0, 0])),
#   (array([0.00784314, 0.07843137, 0.03529412, ..., 0.01960784, 0.00784314,
#           0.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.        , 0.        , ..., 0.00784314, 0.00392157,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.06666667, 0.0627451 ,
#           0.01960784]),
#    array([0, 0, 0, 1])),
#   (array([0.00784314, 0.07843137, 0.00784314, ..., 0.01176471, 0.02352941,
#           0.01568627]),
#    array([0, 1, 0, 0])),
#   (array([0.08627451, 0.04313725, 0.06666667, ..., 0.98431373, 0.99215686,
#           1.        ]),
#    array([1, 0, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.08235294, 0.03921569,
#           0.89803922]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.05882353, 0.01568627,
#           0.01176471]),
#    array([0, 0, 0, 1])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.01176471,
#           0.90196078]),
#    array([0, 0, 0, 1])),
#   (array([0.02745098, 0.00392157, 0.        , ..., 0.        , 0.        ,
#           0.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.99607843, 1.        , 1.        , ..., 0.01176471, 0.00392157,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([1., 1., 1., ..., 1., 1., 1.]), array([0, 0, 1, 0])),
#   (array([0.07843137, 0.07843137, 0.08235294, ..., 0.00392157, 0.01568627,
#           0.        ]),
#    array([0, 1, 0, 0])),
#   (array([0.        , 0.        , 0.01568627, ..., 0.0627451 , 0.05882353,
#           0.0745098 ]),
#    array([1, 0, 0, 0])),
#   (array([0.08235294, 0.09411765, 0.16470588, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.13333333, 0.02352941, 0.21568627, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03921569, 0.05490196,
#           0.90196078]),
#    array([0, 1, 0, 0])),
#   (array([0.00784314, 0.02745098, 0.03137255, ..., 0.01176471, 0.00784314,
#           0.02352941]),
#    array([0, 1, 0, 0])),
#   (array([0.04313725, 0.00392157, 0.0745098 , ..., 0.00784314, 0.01568627,
#           0.01960784]),
#    array([1, 0, 0, 0])),
#   (array([0.05098039, 0.03137255, 0.00784314, ..., 0.01176471, 0.01176471,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.04313725, 0.05490196,
#           1.        ]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02352941, 0.70588235,
#           0.99607843]),
#    array([0, 1, 0, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.02745098, 0.00392157,
#           0.89803922]),
#    array([0, 0, 0, 1])),
#   (array([0.19215686, 0.08627451, 0.1372549 , ..., 1.        , 0.97647059,
#           0.97647059]),
#    array([1, 0, 0, 0])),
#   (array([0.09803922, 0.14117647, 0.13333333, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 1, 0])),
#   (array([0.00784314, 0.02745098, 0.03137255, ..., 0.01176471, 0.00784314,
#           0.02352941]),
#    array([0, 1, 0, 0])),
#   (array([0.03137255, 0.02745098, 0.05882353, ..., 0.01568627, 0.01176471,
#           0.00784314]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.08627451, 0.08235294, ..., 0.02745098, 0.03529412,
#           0.00784314]),
#    array([1, 0, 0, 0])),
#   (array([0.00784314, 0.03529412, 0.12941176, ..., 0.01176471, 0.00392157,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.07843137, 0.        , 0.0745098 , ..., 0.01960784, 0.01176471,
#           0.01176471]),
#    array([1, 0, 0, 0])),
#   (array([0.00392157, 0.00784314, 0.02745098, ..., 0.00784314, 0.01568627,
#           0.00784314]),
#    array([0, 1, 0, 0])),
#   (array([0.99607843, 1.        , 0.98039216, ..., 0.02745098, 0.03137255,
#           0.00392157]),
#    array([1, 0, 0, 0])),
#   (array([0.01176471, 0.03529412, 0.00784314, ..., 0.00392157, 0.        ,
#           0.        ]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.16470588, 0.0745098 , ..., 0.01176471, 0.05490196,
#           0.04705882]),
#    array([0, 0, 1, 0])),
#   (array([1.        , 1.        , 1.        , ..., 0.03137255, 0.01960784,
#           0.03529412]),
#    array([0, 0, 0, 1])),
#   (array([0.18823529, 0.19607843, 0.20392157, ..., 1.        , 1.        ,
#           1.        ]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.03137255, 0.06666667, ..., 0.00784314, 0.01960784,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.        , 0.        , 0.01960784, ..., 0.00784314, 0.01568627,
#           0.00392157]),
#    array([0, 0, 0, 1])),
#   (array([0.90980392, 0.07058824, 0.14117647, ..., 0.03137255, 0.03921569,
#           0.03529412]),
#    array([1, 0, 0, 0])),
#   (array([0.04313725, 0.00784314, 0.04313725, ..., 0.00784314, 0.00784314,
#           0.00392157]),
#    array([0, 1, 0, 0])),
#   (array([0.1254902 , 0.11372549, 0.11764706, ..., 0.01176471, 0.01960784,
#           0.01568627]),
#    array([0, 0, 0, 1])),
#   (array([0.07843137, 0.18431373, 0.14901961, ..., 0.00392157, 0.01568627,
#           0.03529412]),
#    array([1, 0, 0, 0])),
#   (array([0.        , 0.0745098 , 0.08235294, ..., 0.99607843, 0.99607843,
#           0.91372549]),
#    array([1, 0, 0, 0]))]}

# %%
def batch_data(data_shard, bs=32):

    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)

# %%
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(tf.ragged.constant(data))
    

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

# %%
class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(200, input_shape=(25600,)))
        model.add(Activation("relu"))
        model.add(Dense(200))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("softmax"))
        return model

# %%
lr = 0.01 
comms_round = 100
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer = SGD(lr=lr, 
                decay=lr / comms_round, 
                momentum=0.9
               )
# Out:
# C:\Users\jains\AppData\Roaming\Python\Python39\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
   
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
   
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
 
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
  
    avg_grad = list()
  
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
 
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss

# %%
#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build(784, 4)
        

for comm_round in range(comms_round):
            
 
    global_weights = global_model.get_weights()
  
    scaled_local_weight_list = list()

   
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
   
    for client in client_names:
        smlp_local = SimpleMLP()
        local_model = smlp_local.build(784, 4)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)

        local_model.set_weights(global_weights)
        
       
        local_model.fit(clients_batched[client], epochs=3, verbose=0)
        
       
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        K.clear_session()
        
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    global_model.set_weights(average_weights)

    
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
# Out:
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 0 | global_acc: 40.476% | global_loss: 1.3583686351776123
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 1 | global_acc: 41.667% | global_loss: 1.3145051002502441
# 3/3 [==============================] - 0s 9ms/step
# comm_round: 2 | global_acc: 58.333% | global_loss: 1.2911036014556885
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 3 | global_acc: 53.571% | global_loss: 1.2364603281021118
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 4 | global_acc: 58.333% | global_loss: 1.2354830503463745
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 5 | global_acc: 64.286% | global_loss: 1.1926079988479614
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 6 | global_acc: 61.905% | global_loss: 1.1751922369003296
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 7 | global_acc: 65.476% | global_loss: 1.1535711288452148
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 8 | global_acc: 71.429% | global_loss: 1.1309199333190918
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 9 | global_acc: 70.238% | global_loss: 1.1162428855895996
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 10 | global_acc: 75.000% | global_loss: 1.1018877029418945
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 11 | global_acc: 73.810% | global_loss: 1.0899454355239868
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 12 | global_acc: 69.048% | global_loss: 1.1014926433563232
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 13 | global_acc: 73.810% | global_loss: 1.0911661386489868
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 14 | global_acc: 73.810% | global_loss: 1.0618541240692139
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 15 | global_acc: 78.571% | global_loss: 1.0505585670471191
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 16 | global_acc: 72.619% | global_loss: 1.0520200729370117
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 17 | global_acc: 73.810% | global_loss: 1.0377658605575562
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 18 | global_acc: 73.810% | global_loss: 1.0261503458023071
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 19 | global_acc: 76.190% | global_loss: 1.0242067575454712
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 20 | global_acc: 76.190% | global_loss: 1.014448881149292
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 21 | global_acc: 77.381% | global_loss: 1.005675196647644
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 22 | global_acc: 77.381% | global_loss: 1.0133644342422485
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 23 | global_acc: 77.381% | global_loss: 0.9999797344207764
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 24 | global_acc: 77.381% | global_loss: 0.9971597790718079
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 25 | global_acc: 77.381% | global_loss: 0.997717022895813
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 26 | global_acc: 79.762% | global_loss: 0.9954991936683655
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 27 | global_acc: 77.381% | global_loss: 0.995564341545105
# 3/3 [==============================] - 0s 9ms/step
# comm_round: 28 | global_acc: 78.571% | global_loss: 0.9835801720619202
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 29 | global_acc: 79.762% | global_loss: 0.9810448884963989
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 30 | global_acc: 79.762% | global_loss: 0.9760563969612122
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 31 | global_acc: 78.571% | global_loss: 0.9773820042610168
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 32 | global_acc: 79.762% | global_loss: 0.9720920324325562
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 33 | global_acc: 78.571% | global_loss: 0.973662257194519
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 34 | global_acc: 79.762% | global_loss: 0.969031035900116
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 35 | global_acc: 79.762% | global_loss: 0.9740133881568909
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 36 | global_acc: 78.571% | global_loss: 0.9694201946258545
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 37 | global_acc: 79.762% | global_loss: 0.9635188579559326
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 38 | global_acc: 79.762% | global_loss: 0.9641921520233154
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 39 | global_acc: 79.762% | global_loss: 0.9612300395965576
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 40 | global_acc: 79.762% | global_loss: 0.9629469513893127
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 41 | global_acc: 79.762% | global_loss: 0.9613900184631348
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 42 | global_acc: 78.571% | global_loss: 0.9606390595436096
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 43 | global_acc: 78.571% | global_loss: 0.9599621295928955
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 44 | global_acc: 78.571% | global_loss: 0.9573700428009033
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 45 | global_acc: 78.571% | global_loss: 0.9592592120170593
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 46 | global_acc: 78.571% | global_loss: 0.9569262266159058
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 47 | global_acc: 78.571% | global_loss: 0.9560986757278442
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 48 | global_acc: 79.762% | global_loss: 0.9579765796661377
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 49 | global_acc: 78.571% | global_loss: 0.9563611149787903
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 50 | global_acc: 78.571% | global_loss: 0.9557398557662964
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 51 | global_acc: 78.571% | global_loss: 0.9539999961853027
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 52 | global_acc: 78.571% | global_loss: 0.9541736841201782
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 53 | global_acc: 78.571% | global_loss: 0.953247606754303
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 54 | global_acc: 78.571% | global_loss: 0.9525293707847595
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 55 | global_acc: 78.571% | global_loss: 0.9532435536384583
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 56 | global_acc: 78.571% | global_loss: 0.9520643949508667
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 57 | global_acc: 78.571% | global_loss: 0.9515097737312317
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 58 | global_acc: 78.571% | global_loss: 0.9517340064048767
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 59 | global_acc: 78.571% | global_loss: 0.9517395496368408
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 60 | global_acc: 78.571% | global_loss: 0.9507279396057129
# 3/3 [==============================] - 0s 14ms/step
# comm_round: 61 | global_acc: 78.571% | global_loss: 0.9500482678413391
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 62 | global_acc: 78.571% | global_loss: 0.9506627321243286
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 63 | global_acc: 78.571% | global_loss: 0.9501897096633911
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 64 | global_acc: 78.571% | global_loss: 0.9504672288894653
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 65 | global_acc: 78.571% | global_loss: 0.9493840336799622
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 66 | global_acc: 78.571% | global_loss: 0.9492372870445251
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 67 | global_acc: 78.571% | global_loss: 0.9482477903366089
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 68 | global_acc: 78.571% | global_loss: 0.9483562707901001
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 69 | global_acc: 78.571% | global_loss: 0.9485734105110168
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 70 | global_acc: 78.571% | global_loss: 0.9481164813041687
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 71 | global_acc: 78.571% | global_loss: 0.9481327533721924
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 72 | global_acc: 78.571% | global_loss: 0.9482845067977905
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 73 | global_acc: 78.571% | global_loss: 0.9479529857635498
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 74 | global_acc: 78.571% | global_loss: 0.9477335810661316
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 75 | global_acc: 78.571% | global_loss: 0.947672963142395
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 76 | global_acc: 78.571% | global_loss: 0.9477421641349792
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 77 | global_acc: 78.571% | global_loss: 0.9470863342285156
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 78 | global_acc: 78.571% | global_loss: 0.9476016163825989
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 79 | global_acc: 78.571% | global_loss: 0.9469913244247437
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 80 | global_acc: 78.571% | global_loss: 0.9468817710876465
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 81 | global_acc: 78.571% | global_loss: 0.9461662769317627
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 82 | global_acc: 78.571% | global_loss: 0.9466620087623596
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 83 | global_acc: 78.571% | global_loss: 0.9461737871170044
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 84 | global_acc: 78.571% | global_loss: 0.946305513381958
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 85 | global_acc: 78.571% | global_loss: 0.9459540843963623
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 86 | global_acc: 78.571% | global_loss: 0.9460083842277527
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 87 | global_acc: 78.571% | global_loss: 0.9455510377883911
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 88 | global_acc: 78.571% | global_loss: 0.9460171461105347
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 89 | global_acc: 78.571% | global_loss: 0.9456270933151245
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 90 | global_acc: 78.571% | global_loss: 0.9457756876945496
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 91 | global_acc: 78.571% | global_loss: 0.9459684491157532
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 92 | global_acc: 78.571% | global_loss: 0.9457645416259766
# 3/3 [==============================] - 0s 5ms/step
# comm_round: 93 | global_acc: 78.571% | global_loss: 0.945154070854187
# 3/3 [==============================] - 0s 8ms/step
# comm_round: 94 | global_acc: 78.571% | global_loss: 0.9457362294197083
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 95 | global_acc: 78.571% | global_loss: 0.9452620148658752
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 96 | global_acc: 78.571% | global_loss: 0.9452904462814331
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 97 | global_acc: 78.571% | global_loss: 0.9448830485343933
# 3/3 [==============================] - 0s 7ms/step
# comm_round: 98 | global_acc: 78.571% | global_loss: 0.9453317523002625
# 3/3 [==============================] - 0s 6ms/step
# comm_round: 99 | global_acc: 78.571% | global_loss: 0.9447407722473145

# %%
def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss
